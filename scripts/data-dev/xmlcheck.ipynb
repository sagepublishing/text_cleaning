# %%
import pandas as pd
import numpy as np
from xml.etree.ElementTree import parse

import spacy

# %%
document = parse('./traveladvisory.xml')

# %%
print(document)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x10b0559d0>

# %%
print(dir(document))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_root', '_setroot', 'find', 'findall', 'findtext', 'getiterator', 'getroot', 'iter', 'iterfind', 'parse', 'write', 'write_c14n']

# %%
root = document.getroot()

# %%
root.attrib
# Out:
# {}

# %%
[child.tag for child in root[7].iter()]
# Out:
# ['{http://www.w3.org/2005/Atom}entry',
#  '{http://www.w3.org/2005/Atom}title',
#  '{http://www.w3.org/2005/Atom}author',
#  '{http://www.w3.org/2005/Atom}email',
#  '{http://www.w3.org/2005/Atom}name',
#  '{http://www.w3.org/2005/Atom}uri',
#  '{http://www.w3.org/2005/Atom}link',
#  '{http://www.w3.org/2005/Atom}category',
#  '{http://www.w3.org/2005/Atom}category',
#  '{http://www.w3.org/2005/Atom}category',
#  '{http://www.w3.org/2005/Atom}summary',
#  '{http://www.w3.org/2005/Atom}id',
#  '{http://www.w3.org/2005/Atom}published',
#  '{http://www.w3.org/2005/Atom}updated']

# %%
for child in root:
    print(child.tag, child.attrib)

# %% [markdown]
# # Extract text
# ## Inspect structure

# %%
# advisory path
for item in document.iterfind('http://www.w3.org/2005/Atom}entry'):
    print(item)

# %%
for item in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    print(item.findtext('{http://www.w3.org/2005/Atom}title'))

# %%
for item in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    print(item.findtext('{http://www.w3.org/2005/Atom}summary'))

# %%
for entry in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    for author in entry.findall('{http://www.w3.org/2005/Atom}author'):
        print(author.findtext('{http://www.w3.org/2005/Atom}name'))

# %%
for entry in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    for category in entry.iter('{http://www.w3.org/2005/Atom}category'):
        print(category.attrib)

# %%
for entry in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    for category in entry.iter('{http://www.w3.org/2005/Atom}category'):
        name = category.get('label')
        term = category.get('term')
        print(name, term)

# %%
for item in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    for link in (item.iter('{http://www.w3.org/2005/Atom}link')):
        print(link.get('href'))

# %% [markdown]
# ## Create dataframe

# %%
title = []
link = []
summary = []
date_published = []
date_updated = []

# %%
for item in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    title.append(item.findtext('{http://www.w3.org/2005/Atom}title'))
    summary.append(item.findtext('{http://www.w3.org/2005/Atom}summary'))
    date_published.append(item.findtext('{http://www.w3.org/2005/Atom}published'))
    date_updated.append(item.findtext('{http://www.w3.org/2005/Atom}updated'))
    
    for links in (item.iter('{http://www.w3.org/2005/Atom}link')):
        link.append(links.get('href'))

# %%
df = pd.DataFrame({'title': title, 'link': link, 'summary': summary, 
                   'date_published': date_published, "date_updated":date_updated})

# %%
df.head(3)
# Out:
#                                                title  \
# 0  Liechtenstein - Level 1: Exercise Normal Preca...
# 1  North Macedonia - Level 1: Exercise Normal Pre...
# 2       Nauru - Level 1: Exercise Normal Precautions
#
#                                                 link  \
# 0  https://travel.state.gov/content/travel/en/tra...
# 1  https://travel.state.gov/content/travel/en/tra...
# 2  https://travel.state.gov/content/travel/en/tra...
#
#                                              summary  \
# 0  <p><b>Global Health Advisory: Do Not Travel. A...
# 1  <p><b>Global Health Advisory: Do Not Travel. A...
# 2  <p><b>Global Health Advisory: Do Not Travel. A...
#
#              date_published              date_updated
# 0  2019-02-19T15:59:21.369Z  2020-03-24T19:27:00.135Z
# 1  2019-02-19T15:59:21.369Z  2020-03-24T20:17:25.924Z
# 2  2019-02-19T15:59:21.369Z  2020-03-24T20:06:39.217Z

# %%
# ran into incorrect lengths because published and updated were in the summary text as well
print(len(date_published))
print(len(title))
print(len(date_updated))
# Out:
# 209
# 209
# 209

# %%
terms = []
for entry in document.iterfind('{http://www.w3.org/2005/Atom}entry'):
    for category in entry.iter('{http://www.w3.org/2005/Atom}category'):
        label = category.get('label')
        term = category.get('term')
        tuples = (label, term)
        terms.append(tuples)

# %%
zipObj = zip(terms)
dictionary = dict(zipObj)

# %%
dictionary['Country-Tag'] =
# Out:
# {'Country-Tag': 'CF',
#  'Keyword': 'advisory',
#  'Threat-Level': 'Level 2: Exercise Increased Caution'}

# %% [markdown]
# # Text Cleaning

# %%
df['summary'][3]
# Out:
# '<p><b>Global Health Advisory: Do Not Travel. Avoid all international travel due to the global impact of&nbsp;<a href="https://travel.state.gov/content/travel/en/traveladvisories/ea/travel-advisory-alert-global-level-4-health-advisory-issue.html">COVID-19</a>.</b></p>\n<p>Exercise normal precautions in Palau.</p>\n<p>Read the Safety and Security section on the <a href="https://travel.state.gov/content/travel/en/international-travel/International-Travel-Country-Information-Pages/Palau.html">country information page</a>.</p>\n<p>If you decide to travel to Palau:</p>\n<ul>\n<li>Enroll in the <a href="https://step.state.gov/step/">Smart Traveler Enrollment Program</a> (<a href="https://step.state.gov/step/">STEP</a>) to receive security messages and make it easier to locate you in an emergency.</li>\n<li>Follow the Department of State on <a href="https://www.facebook.com/travelgov/">Facebook</a> and <a href="https://twitter.com/TravelGov">Twitter</a>.</li>\n<li>U.S. citizens who travel abroad should always have a contingency plan for emergency situations. Review the <a href="https://travel.state.gov/content/passports/en/go/checklist.html">Traveler’s Checklist</a>.</li>\n</ul>\n<p><i>Last Updated: Reissued after periodic review without changes.</i></p>\n'

# %%
import re

TAG_RE = re.compile(r'<[^>]+>')

def remove_tags(text):
    return TAG_RE.sub('', text)

# %%
test = remove_tags(df['summary'][3])

# %%
test = test.replace('\n', '').replace('&nbsp;', ' ')

test
# Out:
# 'Global Health Advisory: Do Not Travel. Avoid all international travel due to the global impact ofCOVID-19.Exercise normal precautions in Palau.Read the Safety and Security section on the country information page.If you decide to travel to Palau:Enroll in the Smart Traveler Enrollment Program (STEP) to receive security messages and make it easier to locate you in an emergency.Follow the Department of State on Facebook and Twitter.U.S. citizens who travel abroad should always have a contingency plan for emergency situations. Review the Traveler’s Checklist.Last Updated: Reissued after periodic review without changes.'

# %%
# function to remove html tags and to clean up script

def clean_text(texts):
    clean_texts = []
    for text in texts:
        text = TAG_RE.sub('', text) #includes url links as well
        text = text.replace('\n', '').replace('&nbsp;', ' ')
        clean_texts.append(text)
    return clean_texts

# %%
df['summary'] = clean_text(df['summary'] )

# %%
#inspect
df['summary'][5]
# Out:
# "This latest update to the Department of State’s Worldwide Caution provides U.S. citizens with general information regarding terrorist activities, political violence and criminal activity that transpire abroad, as well as specific recommendations on how to prepare for possible contingencies, receive information on breaking security events and ensure that travelers can be contacted in an emergency. This version replaces the Worldwide Caution dated July 2, 2018.As terrorist attacks, political violence (including demonstrations), criminal activities and other security incidents often take place without any warning, U.S. citizens are strongly encouraged to maintain a high level of vigilance and practice good situational awareness when traveling abroad. When planning a trip and prior to departing the United States, U.S. citizens should consult country specific Travel Advisories and information pages on travel.state.gov.Travelers are also urged to enroll in the Smart Traveler Enrollment Program (STEP) to receive security messages and to make it easier to locate you in an emergency. The Department uses these security messages to convey information about terrorist threats, security incidents, planned demonstrations, natural disasters, etc. In an emergency, please contact the nearest U.S. Embassy or consulate or call the following numbers: 1 (888) 407-4747 (toll-free in the United States and Canada) or 1 (202) 501-4444 from other countries.U.S. government facilities worldwide actively monitor potential security threats and may temporarily close or periodically suspend public services to assess their security posture. In those instances, U.S. embassies and consulates will make every effort to provide emergency services to U.S. citizens. U.S. citizens abroad are urged to monitor the local news and maintain contact with the nearest U.S. Embassy or consulate.Terrorist groups including ISIS, al-Qa'ida, their associates, and those inspired by such organizations, are intent on attacking U.S. citizens wherever they are. Extremists may use conventional or non-conventional weapons to target U.S. government and private interests. Terrorists are increasingly using less sophisticated methods, including edged weapons, pistols and vehicles, as weapons to effectively target crowds. Extremists increasingly aim to identify and attack &quot;soft&quot; targets, such as:high-profile public events (sporting contests, political rallies, demonstrations, holiday events, celebratory gatherings, etc.)hotels, clubs and restaurantsplaces of worshipschoolsparksshopping malls and marketstourism infrastructure and tourist sitespublic transportation systemsairportsIn multiple regions, terrorists, guerrilla groups and criminals seek to kidnap U.S. citizens to finance their operations or for political purposes. The Department also remains concerned that terrorists could again seek to down aircraft using concealed explosives or hijack commercial flights.Private U.S. citizens should not travel to any country to participate in armed conflict. U.S. citizens are reminded that fighting on behalf of, or providing other forms of support to, designated terrorist organizations can constitute the provision of material support for terrorism, which is a serious crime that can result in penalties, including prison time and large fines. For further information:See the Department of State's travel website for the Worldwide Caution, Travel Advisories, and country information.Follow us on Twitter and Facebook and Instagram.The Department of State's Overseas Security Advisory Council (OSAC) provides several resources to enhance the safety and security of the U.S. private sector abroad. Additional information on OSAC can be found on OSAC.gov or by following OSAC on Twitter.Mariners and U.S. citizens considering maritime travel should also review information at the websites of the National Geospatial Agency, the Maritime Security Communications with Industry Portal, and the U.S. Coast Guard ...

# %% [markdown]
# ## Alternative parsing method

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import xmltodict

# %%
with open('./traveladvisory.xml') as fd:
    advisory_dictionary = xmltodict.parse(fd.read())

# %%
advisory_dictionary['feed']['entry'][2]
# Out:
# OrderedDict([('title',
#               OrderedDict([('@type', 'html'),
#                            ('#text',
#                             'Nauru - Level 1: Exercise Normal Precautions')])),
#              ('author',
#               OrderedDict([('email', 'none'),
#                            ('name', 'TSG'),
#                            ('uri', 'https://travel.state.gov')])),
#              ('link',
#               OrderedDict([('@href',
#                             'https://travel.state.gov/content/travel/en/traveladvisories/traveladvisories/nauru-travel-advisory.html')])),
#              ('category',
#               [OrderedDict([('@label', 'Country-Tag'), ('@term', 'NR')]),
#                OrderedDict([('@label', 'Keyword'), ('@term', 'advisory')]),
#                OrderedDict([('@label', 'Threat-Level'),
#                             ('@term',
#                              'Level 1: Exercise Normal Precautions')])]),
#              ('summary',
#               OrderedDict([('@type', 'html'),
#                            ('#text',
#                             '<p><b>Global Health Advisory: Do Not Travel. Avoid all international travel due to the global impact of&nbsp;<a href="https://travel.state.gov/content/travel/en/traveladvisories/ea/travel-advisory-alert-global-level-4-health-advisory-issue.html">COVID-19</a>.</b></p>\n<p>Exercise normal precautions in Nauru.</p>\n<p>Read the Safety and Security section on the <a adhocenable="false" href="/content/travel/en/international-travel/International-Travel-Country-Information-Pages/Nauru.html">country information page</a>.</p>\n<p>If you decide to travel to Nauru:</p>\n<ul>\n<li>Enroll in the <a href="https://step.state.gov/step/">Smart Traveler Enrollment Program</a> (<a href="https://step.state.gov/step/">STEP</a>) to receive security messages and make it easier to locate you in an emergency.</li>\n<li>Follow the Department of State on <a href="https://www.facebook.com/travelgov/">Facebook</a> and <a href="https://twitter.com/TravelGov">Twitter</a>.</li>\n<li>U.S. citizens who travel abroad should always have a contingency plan for emergency situations. Review the <a href="https://travel.state.gov/content/passports/en/go/checklist.html">Traveler’s Checklist</a>.</li>\n</ul>\n<p><b><i>Last Update: Reissued after periodic review without changes.</i></b></p>')])),
#              ('id',
#               'https://travel.state.gov/content/travel/en/traveladvisories/traveladvisories/nauru-travel-advisory.html'),
#              ('published', '2019-02-19T15:59:21.369Z'),
#              ('updated', '2020-03-24T20:06:39.217Z')])

# %% [markdown]
# # Reflections
# 4 hours -
#
# This was my first time working with XML. I found that the most time consuming part was the inspection of tree structure and in particular getting the information within a nested subtree. I'm sure there are faster approaches out there, but it definitely helps to view/know the structure.
#
# Other - text cleaning, paragraph structure lost. Cleaning scripts may depend on what type of analysis - word emebedding or paragraph/document embedding.
#
# Useful resources:
# - <a href="https://towardsdatascience.com/parsing-xml-data-in-python-da26288280e1">basic XML parsing</a>
# - <a href="https://docs.python.org/2/library/xml.etree.elementtree.html">documentation </a>
# - <a href="https://tutorialedge.net/python/removing-html-from-string/">html script cleaning</a>
# - <a href="https://docs.python-guide.org/scenarios/xml/">xmltodict</a>

# %% [markdown]
# # JSON /API
#
# Veteran Affairs
# https://www.va.gov/webservices/press/documentation/releases.cfm
# - Documentation page not maintained, 500 internal errors when looking at demos (Perhaps a common problem)
#
# OpenFEC
# - API for Federal Election Commission filings
# - https://api.open.fec.gov/developers/

# %%
import requests

# %%
response = requests.get("https://developer.nrel.gov/api/alt-fuel-stations/v1/nearest.json?api_key=Z9SNbTyUefPgAdhjZfqPIrCUSqTtfTYlVMeliTN2&location=Denver+CO")
print(response.status_code)
# Out:
# 200

# %%
import json

# %%
# committee id fundings
ted_cruz = requests.get("https://api.open.fec.gov/v1/candidate/S2TX00312/filings/?party=REP&most_recent=true&max_receipt_date=01%2F01%2F2020&per_page=20&sort=-receipt_date&sort_hide_null=false&api_key=Z9SNbTyUefPgAdhjZfqPIrCUSqTtfTYlVMeliTN2&sort_nulls_last=false&sort_null_only=false&page=1")


td_data = ted_cruz.json()

# %%
print(td_data)
# Out:
# {'api_version': '1.0', 'results': [{'committee_name': None, 'senate_personal_funds': None, 'cash_on_hand_beginning_period': None, 'candidate_id': 'S2TX00312', 'sub_id': '4120720181620534585', 'debts_owed_by_committee': None, 'cycle': 2018, 'net_donations': None, 'house_personal_funds': None, 'total_receipts': None, 'total_independent_expenditures': None, 'document_type_full': None, 'treasurer_name': None, 'update_date': '2018-12-07T21:00:34', 'debts_owed_to_committee': None, 'total_communication_cost': None, 'request_type': None, 'beginning_image_number': '201812069134971099', 'total_individual_contributions': None, 'ending_image_number': '201812069134971100', 'html_url': 'http://docquery.fec.gov/cgi-bin/forms/S2TX00312/1299312/', 'is_amended': False, 'state': 'TX', 'fec_url': 'http://docquery.fec.gov/dcdev/posted/1299312.fec', 'document_description': 'Statement of candidacy 2018', 'cash_on_hand_end_period': None, 'receipt_date': '2018-12-06T00:00:00', 'report_type': None, 'csv_url': 'http://docquery.fec.gov/csv/312/1299312.csv', 'form_type': 'F2', 'total_disbursements': None, 'amendment_indicator': 'N', 'document_type': None, 'form_category': 'STATEMENT', 'pages': 2, 'committee_id': 'S2TX00312', 'office': 'S', 'coverage_end_date': None, 'fec_file_id': 'FEC-1299312', 'file_number': 1299312, 'most_recent_file_number': 1299312, 'amendment_version': 6, 'candidate_name': 'CRUZ, RAFAEL EDWARD  TED', 'report_type_full': None, 'primary_general_indicator': None, 'pdf_url': 'http://docquery.fec.gov/pdf/099/201812069134971099/201812069134971099.pdf', 'previous_file_number': 1272203, 'amendment_chain': [-465940.0, -2743827.0, -2805827.0, -7839830.0, -9550180.0, 1272203.0, 1299312.0], 'opposition_personal_funds': None, 'report_year': 2018, 'most_recent': True, 'means_filed': 'e-file', 'election_year': 2024, 'committee_type': None, 'party': 'REP', 'coverage_start_date': None}], 'pagination': {'pages': 1, 'page': 1, 'count': 1, 'per_page': 20}}

# %%
## No filings with the query

td_df = pd.DataFrame(td_data["results"])

# %%
td_df
# Out:
#   total_communication_cost                                            pdf_url  \
# 0                     None  http://docquery.fec.gov/pdf/099/20181206913497...
#
#   debts_owed_to_committee  amendment_version office committee_type  \
# 0                    None                  6      S           None
#
#   beginning_image_number cash_on_hand_beginning_period house_personal_funds  \
# 0     201812069134971099                          None                 None
#
#   form_type  ... most_recent_file_number senate_personal_funds party  \
# 0        F2  ...                 1299312                  None   REP
#
#   committee_name previous_file_number report_type treasurer_name  \
# 0           None              1272203        None           None
#
#              candidate_name net_donations total_receipts
# 0  CRUZ, RAFAEL EDWARD  TED          None           None
#
# [1 rows x 56 columns]

# %% [markdown]
# ### committee id fundings

# %% [markdown]
# resource: https://github.com/NickyThreeNames/openFEC/blob/master/FECOpenAPI.ipynb

# %%
url = "https://api.open.fec.gov/v1/committee/C00492785/filings/"

params = {'party': "REP",
         "api_key": key,
         }

# %%
data = requests.get("https://api.open.fec.gov/v1/committee/C00492785/filings/?per_page=20&sort=-receipt_date&sort_hide_null=false&api_key=Z9SNbTyUefPgAdhjZfqPIrCUSqTtfTYlVMeliTN2&sort_nulls_last=false&sort_null_only=false&page=1").json()

data['pagination']['count']
# Out:
# 190

# %%
data
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 190, 'pages': 10, 'per_page': 20, 'page': 1},
#  'results': [{'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/454/1399454.csv',
#    'file_number': 1399454,
#    'beginning_image_number': '202004159219170261',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1399454/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q1',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1399454,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4041520201736791057',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1399454.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 1983,
#    'most_recent': True,
#    'amendment_chain': [1399454.0],
#    'candidate_id': None,
#    'document_description': 'APRIL QUARTERLY 2020',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '202004159219172243',
#    'previous_file_number': 1399454,
#    'coverage_start_date': '2020-01-01T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'APRIL QUARTERLY',
#    'report_year': 2020,
#    'total_receipts': 1609400.29,
#    'means_filed': 'e-file',
#    'update_date': '2020-04-15T21:00:00',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1399454',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': 1667690.8,
#    'total_disbursements': 1161990.26,
#    'amendment_indicator': 'N',
#    'form_type': 'F3',
#    'receipt_date': '2020-04-15T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2020-03-31T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/261/202004159219170261/202004159219170261.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 2115100.83},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/702/1378702.csv',
#    'file_number': 1378702,
#    'beginning_image_number': '202001319185070820',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1378702/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'YE',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1378702,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4020220201686493176',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1378702.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 1789,
#    'most_recent': True,
#    'amendment_chain': [1378702.0],
#    'candidate_id': None,
#    'document_description': 'YEAR-END 2019',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '202001319185072608',
#    'previous_file_number': 1378702,
#    'coverage_start_date': '2019-10-01T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'YEAR-END',
#    'report_year': 2019,
#    'total_receipts': 1280448.94,
#    'means_filed': 'e-file',
#    'update_date': '2020-02-02T20:57:00',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1378702',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': 1434045.74,
#    'total_disbursements': 1046803.88,
#    'amendment_indicator': 'N',
#    'form_type': 'F3',
#    'receipt_date': '2020-01-31T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2019-12-31T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/820/202001319185070820/202001319185070820.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 1667690.8},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/191/1358191.csv',
#    'file_number': 1358191,
#    'beginning_image_number': '201910159164218683',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1358191/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q3',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1358191,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4101520191674203668',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1358191.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 1503,
#    'most_recent': True,
#    'amendment_chain': [1358191.0],
#    'candidate_id': None,
#    'document_description': 'OCTOBER QUARTERLY 2019',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201910159164220185',
#    'previous_file_number': 1358191,
#    'coverage_start_date': '2019-07-01T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'OCTOBER QUARTERLY',
#    'report_year': 2019,
#    'total_receipts': 1256635.85,
#    'means_filed': 'e-file',
#    'update_date': '2019-10-15T21:06:27',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1358191',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': 804524.07,
#    'total_disbursements': 627114.18,
#    'amendment_indicator': 'N',
#    'form_type': 'F3',
#    'receipt_date': '2019-10-15T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2019-09-30T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/683/201910159164218683/201910159164218683.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 1434045.74},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': 'http://docquery.fec.gov/csv/493/1349493.csv',
#    'file_number': 1349493,
#    'beginning_image_number': '201908239163101526',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1349493/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'YE',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1349493,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4082320191671052068',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1349493.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 402,
#    'most_recent': True,
#    'amendment_chain': [1312166.0, 1349493.0],
#    'candidate_id': None,
#    'document_description': 'YEAR-END 2018',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201908239163101927',
#    'previous_file_number': 1312166,
#    'coverage_start_date': '2018-11-27T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 1,
#    'report_type_full': 'YEAR-END',
#    'report_year': 2018,
#    'total_receipts': 380795.15,
#    'means_filed': 'e-file',
#    'update_date': '2019-08-23T21:49:07',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1349493',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': 262799.92,
#    'total_disbursements': 485636.43,
#    'amendment_indicator': 'A',
#    'form_type': 'F3',
#    'receipt_date': '2019-08-23T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2018-12-31T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/526/201908239163101526/201908239163101526.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 157958.64},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/495/1349495.csv',
#    'file_number': 1349495,
#    'beginning_image_number': '201908239163102654',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1349495/',
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': None,
#    'house_personal_funds': None,
#    'most_recent_file_number': 1349495,
#    'committee_type': 'S',
#    'document_type_full': 'Miscellaneous Report TO FEC',
#    'election_year': None,
#    'sub_id': '4082320191671052195',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1349495.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 1,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'Miscellaneous Report TO FEC 2019',
#    'form_category': 'OTHER',
#    'document_type': 'T',
#    'request_type': None,
#    'ending_image_number': '201908239163102654',
#    'previous_file_number': 0,
#    'coverage_start_date': None,
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': None,
#    'report_year': 2019,
#    'total_receipts': None,
#    'means_filed': 'e-file',
#    'update_date': '2019-08-23T21:49:21',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1349495',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'F99',
#    'receipt_date': '2019-08-23T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': None,
#    'pdf_url': 'http://docquery.fec.gov/pdf/654/201908239163102654/201908239163102654.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/494/1349494.csv',
#    'file_number': 1349494,
#    'beginning_image_number': '201908239163101928',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1349494/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q1',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1349494,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4082320191671052069',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1349494.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 726,
#    'most_recent': True,
#    'amendment_chain': [1325991.0, 1349494.0],
#    'candidate_id': None,
#    'document_description': 'APRIL QUARTERLY 2019',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201908239163102653',
#    'previous_file_number': 1325991,
#    'coverage_start_date': '2019-01-01T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 1,
#    'report_type_full': 'APRIL QUARTERLY',
#    'report_year': 2019,
#    'total_receipts': 1300687.67,
#    'means_filed': 'e-file',
#    'update_date': '2019-08-23T21:49:07',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1349494',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': 157958.64,
#    'total_disbursements': 664809.18,
#    'amendment_indicator': 'A',
#    'form_type': 'F3',
#    'receipt_date': '2019-08-23T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2019-03-31T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/928/201908239163101928/201908239163101928.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 793837.13},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': None,
#    'file_number': None,
#    'beginning_image_number': '201908210300046660',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': None,
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'YE',
#    'house_personal_funds': None,
#    'most_recent_file_number': None,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '1082120190037516201',
#    'fec_url': 'http://docquery.fec.gov/paper/posted/.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 2,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'RFAI: YEAR-END 2018',
#    'form_category': 'OTHER',
#    'document_type': None,
#    'request_type': '2',
#    'ending_image_number': '201908210300046661',
#    'previous_file_number': 0,
#    'coverage_start_date': '2018-11-27T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'YEAR-END',
#    'report_year': 2018,
#    'total_receipts': None,
#    'means_filed': 'paper',
#    'update_date': '2019-08-21T21:05:28',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': None,
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'FRQ',
#    'receipt_date': '2019-08-21T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2018-12-31T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/660/201908210300046660/201908210300046660.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/530/1340530.csv',
#    'file_number': 1340530,
#    'beginning_image_number': '201907159150884779',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1340530/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q2',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1340530,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4071520191659541259',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340530.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 989,
#    'most_recent': True,
#    'amendment_chain': [1340530.0],
#    'candidate_id': None,
#    'document_description': 'JULY QUARTERLY 2019',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201907159150885767',
#    'previous_file_number': 1340530,
#    'coverage_start_date': '2019-04-01T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'JULY QUARTERLY',
#    'report_year': 2019,
#    'total_receipts': 1072272.2,
#    'means_filed': 'e-file',
#    'update_date': '2019-07-15T20:58:15',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1340530',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': 793837.13,
#    'total_disbursements': 1061585.26,
#    'amendment_indicator': 'N',
#    'form_type': 'F3',
#    'receipt_date': '2019-07-15T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2019-06-30T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/779/201907159150884779/201907159150884779.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 804524.07},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/998/1332998.csv',
#    'file_number': 1332998,
#    'beginning_image_number': '201906049149878039',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1332998/',
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': None,
#    'house_personal_funds': None,
#    'most_recent_file_number': 1332998,
#    'committee_type': 'S',
#    'document_type_full': 'Miscellaneous Report TO FEC',
#    'election_year': None,
#    'sub_id': '4060420191657489765',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1332998.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 1,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'Miscellaneous Report TO FEC 2019',
#    'form_category': 'OTHER',
#    'document_type': 'T',
#    'request_type': None,
#    'ending_image_number': '201906049149878039',
#    'previous_file_number': 0,
#    'coverage_start_date': None,
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': None,
#    'report_year': 2019,
#    'total_receipts': None,
#    'means_filed': 'e-file',
#    'update_date': '2019-06-04T20:57:04',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1332998',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'F99',
#    'receipt_date': '2019-06-04T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': None,
#    'pdf_url': 'http://docquery.fec.gov/pdf/039/201906049149878039/201906049149878039.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/894/1328894.csv',
#    'file_number': 1328894,
#    'beginning_image_number': '201904269149602933',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1328894/',
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': None,
#    'house_personal_funds': None,
#    'most_recent_file_number': 1328894,
#    'committee_type': 'S',
#    'document_type_full': 'Miscellaneous Report TO FEC',
#    'election_year': None,
#    'sub_id': '4042620191647306002',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1328894.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 1,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'Miscellaneous Report TO FEC 2019',
#    'form_category': 'OTHER',
#    'document_type': 'T',
#    'request_type': None,
#    'ending_image_number': '201904269149602933',
#    'previous_file_number': 0,
#    'coverage_start_date': None,
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': None,
#    'report_year': 2019,
#    'total_receipts': None,
#    'means_filed': 'e-file',
#    'update_date': '2019-04-26T20:58:28',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1328894',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'F99',
#    'receipt_date': '2019-04-26T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': None,
#    'pdf_url': 'http://docquery.fec.gov/pdf/933/201904269149602933/201904269149602933.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/785/1328785.csv',
#    'file_number': 1328785,
#    'beginning_image_number': '201904259149596503',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1328785/',
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': None,
#    'house_personal_funds': None,
#    'most_recent_file_number': 1328785,
#    'committee_type': 'S',
#    'document_type_full': 'Miscellaneous Report TO FEC',
#    'election_year': None,
#    'sub_id': '4042520191647271057',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1328785.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 4,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'Miscellaneous Report TO FEC 2019',
#    'form_category': 'OTHER',
#    'document_type': 'T',
#    'request_type': None,
#    'ending_image_number': '201904259149596506',
#    'previous_file_number': 0,
#    'coverage_start_date': None,
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': None,
#    'report_year': 2019,
#    'total_receipts': None,
#    'means_filed': 'e-file',
#    'update_date': '2019-04-25T20:59:08',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1328785',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'F99',
#    'receipt_date': '2019-04-25T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': None,
#    'pdf_url': 'http://docquery.fec.gov/pdf/503/201904259149596503/201904259149596503.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': None,
#    'file_number': None,
#    'beginning_image_number': '201904230300037821',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': None,
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': '30G',
#    'house_personal_funds': None,
#    'most_recent_file_number': None,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '1042320190037495262',
#    'fec_url': 'http://docquery.fec.gov/paper/posted/.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 5,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'RFAI: POST-GENERAL 2018',
#    'form_category': 'OTHER',
#    'document_type': None,
#    'request_type': '2',
#    'ending_image_number': '201904230300037825',
#    'previous_file_number': 0,
#    'coverage_start_date': '2018-10-18T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'POST-GENERAL',
#    'report_year': 2018,
#    'total_receipts': None,
#    'means_filed': 'paper',
#    'update_date': '2019-04-23T21:04:29',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': None,
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'FRQ',
#    'receipt_date': '2019-04-23T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2018-11-26T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/821/201904230300037821/201904230300037821.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': None,
#    'file_number': None,
#    'beginning_image_number': '201904230300037794',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': None,
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q3',
#    'house_personal_funds': None,
#    'most_recent_file_number': None,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '1042320190037495261',
#    'fec_url': 'http://docquery.fec.gov/paper/posted/.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 27,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'RFAI: OCTOBER QUARTERLY 2018',
#    'form_category': 'OTHER',
#    'document_type': None,
#    'request_type': '2',
#    'ending_image_number': '201904230300037820',
#    'previous_file_number': 0,
#    'coverage_start_date': '2018-07-01T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'OCTOBER QUARTERLY',
#    'report_year': 2018,
#    'total_receipts': None,
#    'means_filed': 'paper',
#    'update_date': '2019-04-23T21:04:29',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': None,
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'FRQ',
#    'receipt_date': '2019-04-23T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2018-09-30T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/794/201904230300037794/201904230300037794.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2020,
#    'csv_url': 'http://docquery.fec.gov/csv/991/1325991.csv',
#    'file_number': 1325991,
#    'beginning_image_number': '201904159146200555',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1325991/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q1',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1349494,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4041520191646335777',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1325991.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 726,
#    'most_recent': False,
#    'amendment_chain': [1325991.0],
#    'candidate_id': None,
#    'document_description': 'APRIL QUARTERLY 2019',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201904159146201280',
#    'previous_file_number': 1325991,
#    'coverage_start_date': '2019-01-01T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'APRIL QUARTERLY',
#    'report_year': 2019,
#    'total_receipts': 1300687.67,
#    'means_filed': 'e-file',
#    'update_date': '2019-04-15T21:03:01',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1325991',
#    'is_amended': True,
#    'cash_on_hand_beginning_period': 157958.64,
#    'total_disbursements': 664809.18,
#    'amendment_indicator': 'N',
#    'form_type': 'F3',
#    'receipt_date': '2019-04-15T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2019-03-31T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/555/201904159146200555/201904159146200555.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 793837.13},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2012,
#    'csv_url': 'http://docquery.fec.gov/csv/231/1322231.csv',
#    'file_number': 1322231,
#    'beginning_image_number': '201904010300270569',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/paper_forms/C00492785/1322231/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q2',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1322231,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '1040120190037487033',
#    'fec_url': 'http://docquery.fec.gov/paper/posted/1322231.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 12,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'JULY QUARTERLY 2012',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201904010300270580',
#    'previous_file_number': -1854853,
#    'coverage_start_date': '2012-05-10T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': None,
#    'report_type_full': 'JULY QUARTERLY',
#    'report_year': 2012,
#    'total_receipts': 2685873.0,
#    'means_filed': 'paper',
#    'update_date': '2019-04-04T21:01:17',
#    'debts_owed_by_committee': 795000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1322231',
#    'is_amended': None,
#    'cash_on_hand_beginning_period': 1476210.0,
#    'total_disbursements': 2695704.0,
#    'amendment_indicator': 'A',
#    'form_type': 'F3',
#    'receipt_date': '2019-03-28T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2012-06-30T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/569/201904010300270569/201904010300270569.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 1466379.0},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2012,
#    'csv_url': 'http://docquery.fec.gov/csv/241/1322241.csv',
#    'file_number': 1322241,
#    'beginning_image_number': '201904010300270552',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/paper_forms/C00492785/1322241/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'Q3',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1322241,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '1040120190037481437',
#    'fec_url': 'http://docquery.fec.gov/paper/posted/1322241.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 16,
#    'most_recent': True,
#    'amendment_chain': None,
#    'candidate_id': None,
#    'document_description': 'OCTOBER QUARTERLY 2012',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201904010300270567',
#    'previous_file_number': -2523825,
#    'coverage_start_date': '2012-07-12T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': None,
#    'report_type_full': 'OCTOBER QUARTERLY',
#    'report_year': 2012,
#    'total_receipts': 3927021.0,
#    'means_filed': 'paper',
#    'update_date': '2019-04-04T21:01:17',
#    'debts_owed_by_committee': 1375905.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1322241',
#    'is_amended': None,
#    'cash_on_hand_beginning_period': 1452297.0,
#    'total_disbursements': 3375478.0,
#    'amendment_indicator': 'A',
#    'form_type': 'F3',
#    'receipt_date': '2019-03-28T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2012-09-30T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/552/201904010300270552/201904010300270552.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 2003839.0},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': 'http://docquery.fec.gov/csv/166/1312166.csv',
#    'file_number': 1312166,
#    'beginning_image_number': '201901319145235325',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1312166/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': 'YE',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1349493,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4013120191636950102',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1312166.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 402,
#    'most_recent': False,
#    'amendment_chain': [1312166.0],
#    'candidate_id': None,
#    'document_description': 'YEAR-END 2018',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201901319145235726',
#    'previous_file_number': 1312166,
#    'coverage_start_date': '2018-11-27T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'YEAR-END',
#    'report_year': 2018,
#    'total_receipts': 380795.15,
#    'means_filed': 'e-file',
#    'update_date': '2019-01-31T21:00:10',
#    'debts_owed_by_committee': 10000.0,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1312166',
#    'is_amended': True,
#    'cash_on_hand_beginning_period': 262799.92,
#    'total_disbursements': 485636.43,
#    'amendment_indicator': 'N',
#    'form_type': 'F3',
#    'receipt_date': '2019-01-31T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2018-12-31T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/325/201901319145235325/201901319145235325.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 157958.64},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': 'http://docquery.fec.gov/csv/372/1299372.csv',
#    'file_number': 1299372,
#    'beginning_image_number': '201812069134977477',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1299372/',
#    'debts_owed_to_committee': 0.0,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': '30G',
#    'house_personal_funds': None,
#    'most_recent_file_number': 1299372,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4120720181620534639',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1299372.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 7794,
#    'most_recent': True,
#    'amendment_chain': [1299372.0],
#    'candidate_id': None,
#    'document_description': 'POST-GENERAL 2018',
#    'form_category': 'REPORT',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201812069134985270',
#    'previous_file_number': 1299372,
#    'coverage_start_date': '2018-10-18T00:00:00',
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': 'POST-GENERAL',
#    'report_year': 2018,
#    'total_receipts': 5055944.33,
#    'means_filed': 'e-file',
#    'update_date': '2018-12-07T21:00:41',
#    'debts_owed_by_committee': 360036.06,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1299372',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': 6702089.67,
#    'total_disbursements': 11495234.08,
#    'amendment_indicator': 'N',
#    'form_type': 'F3',
#    'receipt_date': '2018-12-06T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': '2018-11-26T00:00:00',
#    'pdf_url': 'http://docquery.fec.gov/pdf/477/201812069134977477/201812069134977477.pdf',
#    'primary_general_indicator': 'P',
#    'cash_on_hand_end_period': 262799.92},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': 'http://docquery.fec.gov/csv/291/1290291.csv',
#    'file_number': 1290291,
#    'beginning_image_number': '201811059133587894',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1290291/',
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': None,
#    'house_personal_funds': None,
#    'most_recent_file_number': 1290291,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4110520181608660749',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1290291.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 2,
#    'most_recent': None,
#    'amendment_chain': [1290291.0],
#    'candidate_id': None,
#    'document_description': '48-hour notice of contribution/loans received 2018',
#    'form_category': 'NOTICE',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201811059133587895',
#    'previous_file_number': 1290291,
#    'coverage_start_date': None,
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': None,
#    'report_year': 2018,
#    'total_receipts': None,
#    'means_filed': 'e-file',
#    'update_date': '2018-11-05T20:58:36',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1290291',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'F6',
#    'receipt_date': '2018-11-05T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': None,
#    'pdf_url': 'http://docquery.fec.gov/pdf/894/201811059133587894/201811059133587894.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None},
#   {'treasurer_name': None,
#    'net_donations': None,
#    'candidate_name': None,
#    'total_communication_cost': None,
#    'cycle': 2018,
#    'csv_url': 'http://docquery.fec.gov/csv/707/1289707.csv',
#    'file_number': 1289707,
#    'beginning_image_number': '201811039133586041',
#    'committee_name': 'TED CRUZ FOR SENATE',
#    'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00492785/1289707/',
#    'debts_owed_to_committee': None,
#    'total_individual_contributions': None,
#    'party': None,
#    'report_type': None,
#    'house_personal_funds': None,
#    'most_recent_file_number': 1289707,
#    'committee_type': 'S',
#    'document_type_full': None,
#    'election_year': None,
#    'sub_id': '4110320181608631210',
#    'fec_url': 'http://docquery.fec.gov/dcdev/posted/1289707.fec',
#    'office': 'S',
#    'committee_id': 'C00492785',
#    'pages': 9,
#    'most_recent': None,
#    'amendment_chain': [1289707.0],
#    'candidate_id': None,
#    'document_description': '48-hour notice of contribution/loans received 2018',
#    'form_category': 'NOTICE',
#    'document_type': None,
#    'request_type': None,
#    'ending_image_number': '201811039133586049',
#    'previous_file_number': 1289707,
#    'coverage_start_date': None,
#    'senate_personal_funds': None,
#    'amendment_version': 0,
#    'report_type_full': None,
#    'report_year': 2018,
#    'total_receipts': None,
#    'means_filed': 'e-file',
#    'update_date': '2018-11-03T20:56:33',
#    'debts_owed_by_committee': None,
#    'opposition_personal_funds': None,
#    'state': None,
#    'fec_file_id': 'FEC-1289707',
#    'is_amended': False,
#    'cash_on_hand_beginning_period': None,
#    'total_disbursements': None,
#    'amendment_indicator': None,
#    'form_type': 'F6',
#    'receipt_date': '2018-11-03T00:00:00',
#    'total_independent_expenditures': None,
#    'coverage_end_date': None,
#    'pdf_url': 'http://docquery.fec.gov/pdf/041/201811039133586041/201811039133586041.pdf',
#    'primary_general_indicator': None,
#    'cash_on_hand_end_period': None}]}

# %%
df = pd.DataFrame(data["results"])

# %%
df.head()
# Out:
#   treasurer_name net_donations candidate_name total_communication_cost  cycle  \
# 0           None          None           None                     None   2020
# 1           None          None           None                     None   2020
# 2           None          None           None                     None   2020
# 3           None          None           None                     None   2018
# 4           None          None           None                     None   2020
#
#                                        csv_url  file_number  \
# 0  http://docquery.fec.gov/csv/454/1399454.csv    1399454.0
# 1  http://docquery.fec.gov/csv/702/1378702.csv    1378702.0
# 2  http://docquery.fec.gov/csv/191/1358191.csv    1358191.0
# 3  http://docquery.fec.gov/csv/493/1349493.csv    1349493.0
# 4  http://docquery.fec.gov/csv/495/1349495.csv    1349495.0
#
#   beginning_image_number       committee_name  \
# 0     202004159219170261  TED CRUZ FOR SENATE
# 1     202001319185070820  TED CRUZ FOR SENATE
# 2     201910159164218683  TED CRUZ FOR SENATE
# 3     201908239163101526  TED CRUZ FOR SENATE
# 4     201908239163102654  TED CRUZ FOR SENATE
#
#                                             html_url  ...  \
# 0  http://docquery.fec.gov/cgi-bin/forms/C0049278...  ...
# 1  http://docquery.fec.gov/cgi-bin/forms/C0049278...  ...
# 2  http://docquery.fec.gov/cgi-bin/forms/C0049278...  ...
# 3  http://docquery.fec.gov/cgi-bin/forms/C0049278...  ...
# 4  http://docquery.fec.gov/cgi-bin/forms/C0049278...  ...
#
#    cash_on_hand_beginning_period total_disbursements amendment_indicator  \
# 0                     1667690.80          1161990.26                   N
# 1                     1434045.74          1046803.88                   N
# 2                      804524.07           627114.18                   N
# 3                      262799.92           485636.43                   A
# 4                            NaN                 NaN                None
#
#   form_type         receipt_date  total_independent_expenditures  \
# 0        F3  2020-04-15T00:00:00                            None
# 1        F3  2020-01-31T00:00:00                            None
# 2        F3  2019-10-15T00:00:00                            None
# 3        F3  2019-08-23T00:00:00                            None
# 4       F99  2019-08-23T00:00:00                            None
#
#      coverage_end_date                                            pdf_url  \
# 0  2020-03-31T00:00:00  http://docquery.fec.gov/pdf/261/20200415921917...
# 1  2019-12-31T00:00:00  http://docquery.fec.gov/pdf/820/20200131918507...
# 2  2019-09-30T00:00:00  http://docquery.fec.gov/pdf/683/20191015916421...
# 3  2018-12-31T00:00:00  http://docquery.fec.gov/pdf/526/20190823916310...
# 4                 None  http://docquery.fec.gov/pdf/654/20190823916310...
#
#   primary_general_indicator cash_on_hand_end_period
# 0                         P              2115100.83
# 1                         P              1667690.80
# 2                         P              1434045.74
# 3                         P               157958.64
# 4                      None                     NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# # Reflections
#
# Pretty clean, no need for additional text cleaning. Straight forward and well maintained documentation for openFEC with website and GitHub, as opposed to Veteran's Affairs. When converting json dict to dataframe, lost heading metadata. Any way to maintain that?
#
# Would be helpful to have:
# - initial view of results, like a counter to make sure the API made the call or there are results that match
# - error handling in general, used DEM instead of REP for Ted Cruz search param, call completed but there was no data to match
# - how are keys to be maintained? By user or by software?

# %% [markdown]
# ## PDF from url

# %%
## from openFEC API - list of pdfs
# pip install textract & PyPDF2

# import packages
import textract
from PyPDF2 import PdfFileWriter, PdfFileReader

# %%
sample_url = df["pdf_url"][1]

# %%
sample_url
# Out:
# 'http://docquery.fec.gov/pdf/820/202001319185070820/202001319185070820.pdf'

# %%
## initial error - needed to use urllib, pypdf2 is looking for local files
# https://stackoverflow.com/questions/9751197/opening-pdf-urls-with-pypdf

# %%
import urllib.request

pdf_data = urllib.request.urlopen(sample_url).read()

# another error "Remote end closed connection without response"
# same error with requests.get(sample_url, stream = True)

# %%
## try another pdf link

nato_url = "https://www.nato.int/nato_static_fl2014/assets/pdf/2020/3/pdf_publications/sgar19-en.pdf"

# %%
remoteFile = urllib.request.urlopen(nato_url).read()

# %%
import requests
response = requests.get(nato_url)
print(response.text)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Notes - messy foray into pdf from url
#
# List of pdf urls in FEC dataset, but unable to access via requests or urllib. Seems to be too large (over 1000 pages per doc). Tried with a link to a different pdf, a NATO report with over 100 pages, similar findings.
#
# Of course in a tool, the pdf is most likely to be uploaded. Then again, it might be that the user finds all the links in a documents and tries to extract text from that link.
#
# Maybe worth understanding the upload process a bit. It should be easy enough to text clean if the user can identify what kind of analysis is of interest. Other thoughts, user:
#
# - may want to remove html script, but would lose links
# - may want to keep paragraph structure or sentences
# - how to do text cleaning that keeps all types of structure? If a dataframe, a column = tokenized_sent, tokenized_words -- user then has the option to use both as necessary. So two different tracks for text cleaning.
